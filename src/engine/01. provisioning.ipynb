# %% [markdown]
# ## 0.0 Create Azure resources
#
# ### 0.0.1 Create Azure ML Workspace with Azure Portal
#
# If you don't have Microsoft Azure resource, please create it from from [this page](https://azure.microsoft.com/en-us/free/).
#
# Once the resource is prepared, create Azure ML Workspace with [the following instruction](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-manage-workspace?tabs=azure-portal).
# During the instruction, please note the following variables, which will be used in actual scenario:
#
# ![Azure ML Provisioning](../../documentation/images/aml_provisioning.png)
#
# - `subscription`
# - `resource group`
# - `region`
# - `workspace name`
# - `storage account`

# %% [markdown]
# ### 0.0.2 Confirm storage key
#
# Please check storage key in Azure poral with [this site](https://docs.microsoft.com/en-us/azure/storage/common/storage-account-keys-manage?tabs=azure-portal#view-account-access-keys).
#
#
# ### 0.0.3 Create related resource in Cognitive Service from Azure portal
#
# You need two types of resouces:
# - Please create `Speech` resource from [this site](https://docs.microsoft.com/en-us/azure/cognitive-services/cognitive-services-apis-create-account?tabs=speech%2Cwindows#create-a-new-azure-cognitive-services-resource).
# - For `language`, please select `language service` from [this site](https://ms.portal.azure.com/#create/Microsoft.CognitiveServicesTextAnalytics).
#
# Note: Both resouces requires you to use the same variables `subscription`, `resource group` and `region` as Azure ML.
#
# After generating them, please note the `keys` and `endpoint`. For speech servce, please note `location` as well. For your reference, please visit [the site](https://www.youtube.com/watch?v=WZi0fhJtLJI).
#
#
# ### 0.0.4 Authentication
#
# We adopted `CLI` and `managed ID` for AML workspace authentication. Especially, `managed identity` is used for computer cluster in Azure ML. Visit [the site](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-setup-authenticatio), if you're interested in authentication mechanism in Azure ML.

# %% [markdown]
# ## 01. Set variables in local `.env` file
#
# We noted plural variables like `subscription` in the previous section, and we put them into `.env` file for preparing our succeeding process.
# Please put the following format and locate it in `/environment/.env` as local file.
#
# ```.env
# SUBSCRIPTION_ID=AAA
# RESOURCE_GROUP=BBB
# REGION=CCC
# TENANT_ID=DDD
# STORAGE_ACCOUNT=EEE
# SECRET_KEY=DDD
#   :
# ```
#
# Note.  `AAA`, `BBB`, .. are dummy values, and please modify them with your values. Necessary variables are as follows:
#
# | variables in .env  | description                                | # of process |
# |--------------------|--------------------------------------------|--------------|
# | SUBSCRIPTION_ID    | Subscription ID related to Azure account   | 0.0.1        |
# | RESOURCE_GROUP     | Resource group name                        | 0.0.1        |
# | REGION             | Region of Azure account                    | 0.0.1        |
# | TENANT_ID          | Tenant ID of Azure account                 | 0.0.1        |
# | WORKSPACE_NAME     | Workspace name of Azure Machine Learning   | 0.0.1        |
# | STORAGE_ACCOUNT    | Storage account related to AML             | 0.0.1        |
# | SECRET_KEY         | Storage key related to storage account     | 0.0.2        |
# | SPEECH_KEY         | Speech key                                 | 0.0.3        |
# | LOCATION           | Location related to speech key             | 0.0.3        |
# | TEXT_ANALYTICS_KEY | Key for text analytics                     | 0.0.3        |

# %% [markdown]
# ## 0.2 Python environment
#
# ### 0.2.1 Azure ML Compute
#
# Please create [Azure ML Compute instance](https://docs.microsoft.com/en-us/azure/machine-learning/concept-compute-instance#create) with your favorite name, where we execute this script.
#
# ### 0.2.2 Library install
#
# Please install necessary libraries as follows:

# %%
# %pip install -r ../environment/requirements_v2.txt
# Out:
# Requirement already satisfied: python-dotenv in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 1)) (0.21.0)
# Requirement already satisfied: azure-cognitiveservices-speech in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 2)) (1.23.0)
# Collecting azure-ai-ml
#   Downloading azure_ai_ml-1.0.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 7.2 MB/s eta 0:00:01
# Requirement already satisfied: azureml-sdk[contrib,notebooks] in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: jiwer in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 5)) (2.5.1)
# Requirement already satisfied: nltk in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 6)) (3.7)
# Requirement already satisfied: gensim in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 7)) (3.8.3)
# Requirement already satisfied: SoundFile in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 8)) (0.10.3.post1)
# Requirement already satisfied: auto-sklearn in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 9)) (0.14.7)
# Requirement already satisfied: scipy==1.7.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 10)) (1.7.0)
# Requirement already satisfied: pyldavis in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 14)) (3.3.1)
# Requirement already satisfied: enum34 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 15)) (1.1.10)
# Requirement already satisfied: noisereduce in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 16)) (2.0.1)
# Requirement already satisfied: pydub in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 17)) (0.25.1)
# Requirement already satisfied: moviepy in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 18)) (1.0.3)
# Requirement already satisfied: mgrs in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 19)) (1.4.5)
# Requirement already satisfied: azure-storage-file-datalake in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from -r ../environment/requirements_v2.txt (line 20)) (12.8.0)
# Collecting azure-storage-file-share<13.0.0
#   Downloading azure_storage_file_share-12.10.1-py3-none-any.whl (252 kB)
#      |████████████████████████████████| 252 kB 88.7 MB/s eta 0:00:01
# Collecting pydash<6.0.0
#   Downloading pydash-5.1.1-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 5.1 MB/s  eta 0:00:01
# Requirement already satisfied: azure-core!=1.22.0,<2.0.0,>=1.8.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (1.24.2)
# Collecting strictyaml<=1.6.1
#   Downloading strictyaml-1.6.1.tar.gz (137 kB)
#      |████████████████████████████████| 137 kB 90.3 MB/s eta 0:00:01
# Collecting tqdm<=4.63.0
#   Downloading tqdm-4.63.0-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 5.4 MB/s  eta 0:00:01
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (4.9.1)
# Requirement already satisfied: pyjwt<3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (2.4.0)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.10.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (12.13.1)
# Requirement already satisfied: msrest>=0.6.18 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (0.7.1)
# Requirement already satisfied: isodate in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (0.6.1)
# Requirement already satisfied: typing-extensions<5.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (4.3.0)
# Collecting marshmallow<4.0.0,>=3.5
#   Downloading marshmallow-3.18.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 7.2 MB/s  eta 0:00:01
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (6.0)
# Collecting colorama<=0.4.4
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (1.3.0)
# Requirement already satisfied: azure-common<2.0.0,>=1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (1.1.28)
# Requirement already satisfied: azureml-train-automl-client~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-train-core~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-core~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-pipeline~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-dataset-runtime[fuse]~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-contrib-pipeline-steps~=1.44.0; extra == "contrib" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-contrib-services~=1.44.0; extra == "contrib" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-contrib-notebook~=1.44.0; extra == "contrib" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-contrib-server~=1.44.0; extra == "contrib" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-widgets~=1.44.0; extra == "notebooks" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: levenshtein==0.20.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jiwer->-r ../environment/requirements_v2.txt (line 5)) (0.20.2)
# Requirement already satisfied: regex>=2021.8.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nltk->-r ../environment/requirements_v2.txt (line 6)) (2022.7.25)
# Requirement already satisfied: joblib in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nltk->-r ../environment/requirements_v2.txt (line 6)) (0.14.1)
# Requirement already satisfied: click in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nltk->-r ../environment/requirements_v2.txt (line 6)) (7.1.2)
# Requirement already satisfied: smart-open>=1.8.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from gensim->-r ../environment/requirements_v2.txt (line 7)) (1.9.0)
# Requirement already satisfied: numpy>=1.11.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from gensim->-r ../environment/requirements_v2.txt (line 7)) (1.21.6)
# Requirement already satisfied: six>=1.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from gensim->-r ../environment/requirements_v2.txt (line 7)) (1.16.0)
# Requirement already satisfied: cffi>=1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from SoundFile->-r ../environment/requirements_v2.txt (line 8)) (1.15.1)
# Requirement already satisfied: smac<1.3,>=1.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (1.2)
# Requirement already satisfied: distributed>=2012.12 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (2022.9.0)
# Requirement already satisfied: pandas>=1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (1.1.5)
# Requirement already satisfied: pynisher<0.7,>=0.6.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (0.6.4)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (0.24.2)
# Requirement already satisfied: threadpoolctl in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (2.2.0)
# Requirement already satisfied: ConfigSpace<0.5,>=0.4.21 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (0.4.21)
# Requirement already satisfied: setuptools in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (49.6.0)
# Requirement already satisfied: pyrfr<0.9,>=0.8.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (0.8.3)
# Requirement already satisfied: liac-arff in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (2.5.0)
# Requirement already satisfied: distro in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (1.7.0)
# Requirement already satisfied: dask>=2021.12 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (2022.9.0)
# Requirement already satisfied: funcy in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pyldavis->-r ../environment/requirements_v2.txt (line 14)) (1.17)
# Requirement already satisfied: sklearn in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pyldavis->-r ../environment/requirements_v2.txt (line 14)) (0.0)
# Requirement already satisfied: numexpr in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pyldavis->-r ../environment/requirements_v2.txt (line 14)) (2.8.3)
# Requirement already satisfied: future in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pyldavis->-r ../environment/requirements_v2.txt (line 14)) (0.18.2)
# Requirement already satisfied: jinja2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pyldavis->-r ../environment/requirements_v2.txt (line 14)) (2.11.2)
# Requirement already satisfied: librosa in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from noisereduce->-r ../environment/requirements_v2.txt (line 16)) (0.9.2)
# Requirement already satisfied: matplotlib in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from noisereduce->-r ../environment/requirements_v2.txt (line 16)) (3.2.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from moviepy->-r ../environment/requirements_v2.txt (line 18)) (4.4.2)
# Requirement already satisfied: proglog<=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from moviepy->-r ../environment/requirements_v2.txt (line 18)) (0.1.10)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0; python_version >= "3.4" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from moviepy->-r ../environment/requirements_v2.txt (line 18)) (0.4.7)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from moviepy->-r ../environment/requirements_v2.txt (line 18)) (2.28.1)
# Requirement already satisfied: imageio<3.0,>=2.5; python_version >= "3.4" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from moviepy->-r ../environment/requirements_v2.txt (line 18)) (2.21.1)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from mgrs->-r ../environment/requirements_v2.txt (line 19)) (21.3)
# Requirement already satisfied: cryptography>=2.1.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-storage-file-share<13.0.0->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (37.0.4)
# Requirement already satisfied: python-dateutil>=2.6.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from strictyaml<=1.6.1->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (2.8.2)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (0.18.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (5.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.6.18->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (2022.6.15)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.6.18->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (1.3.1)
# Requirement already satisfied: azureml-telemetry~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-client~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-automl-core~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-client~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: knack~=0.9.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.9.0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.9.0)
# Requirement already satisfied: argcomplete<3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2.0.0)
# Requirement already satisfied: pytz in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2019.3)
# Requirement already satisfied: jsonpickle<3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2.2.0)
# Requirement already satisfied: msrestazure<=0.6.4,>=0.4.33 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.6.4)
# Requirement already satisfied: pyopenssl<23.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (22.0.0)
# Requirement already satisfied: pkginfo in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.8.3)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.2.7)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (10.0.0)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (21.6.0)
# Requirement already satisfied: docker<6.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (5.0.3)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (10.0)
# Requirement already satisfied: azure-mgmt-storage<=20.0.0,>=16.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (20.0.0)
# Requirement already satisfied: msal-extensions<=1.0.0,>=0.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.3.1)
# Requirement already satisfied: urllib3<=1.26.9,>=1.23 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.26.9)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.0)
# Requirement already satisfied: azure-mgmt-resource<22.0.0,>=15.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (21.1.0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.5.1)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (10.0.0)
# Requirement already satisfied: jmespath<=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.10.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.61.1)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.18.0)
# Requirement already satisfied: azure-mgmt-authorization<3,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2.0.0)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (3.3.2)
# Requirement already satisfied: paramiko<3.0.0,>=2.0.8 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2.11.0)
# Requirement already satisfied: azureml-pipeline-steps~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-pipeline~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: azureml-pipeline-core~=1.44.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-pipeline~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.44.0)
# Requirement already satisfied: pyarrow<6.0.1,>=0.17.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse]~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (6.0.0)
# Requirement already satisfied: azureml-dataprep<4.3.0a,>=4.2.0a in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse]~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (4.2.2)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse]~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (3.0.1)
# Requirement already satisfied: Flask in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-contrib-services~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.1.4)
# Requirement already satisfied: ipython in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (8.4.0)
# Requirement already satisfied: nbconvert<6 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (5.6.1)
# Requirement already satisfied: jupyter-client<7 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (6.1.12)
# Requirement already satisfied: papermill<2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.2.1)
# Requirement already satisfied: ipykernel in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (6.8.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (7.7.1)
# Requirement already satisfied: markupsafe<2.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2.0.1)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from levenshtein==0.20.2->jiwer->-r ../environment/requirements_v2.txt (line 5)) (2.6.1)
# Requirement already satisfied: boto>=2.32 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from smart-open>=1.8.1->gensim->-r ../environment/requirements_v2.txt (line 7)) (2.49.0)
# Requirement already satisfied: boto3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from smart-open>=1.8.1->gensim->-r ../environment/requirements_v2.txt (line 7)) (1.20.19)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from cffi>=1.0->SoundFile->-r ../environment/requirements_v2.txt (line 8)) (2.21)
# Requirement already satisfied: emcee>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from smac<1.3,>=1.2->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (3.1.2)
# Requirement already satisfied: psutil in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from smac<1.3,>=1.2->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (5.9.1)
# Requirement already satisfied: zict>=0.1.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (2.2.0)
# Requirement already satisfied: tornado<6.2,>=6.0.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (6.1)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (2.4.0)
# Requirement already satisfied: msgpack>=0.6.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (1.0.4)
# Requirement already satisfied: toolz>=0.8.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (0.12.0)
# Requirement already satisfied: tblib>=1.6.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (1.7.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (1.6.0)
# Requirement already satisfied: locket>=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (1.0.0)
# Requirement already satisfied: cython in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (0.29.17)
# Requirement already satisfied: pyparsing in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (3.0.9)
# Requirement already satisfied: fsspec>=0.6.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (2022.7.1)
# Requirement already satisfied: partd>=0.3.10 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (1.2.0)
# Requirement already satisfied: pooch>=1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from librosa->noisereduce->-r ../environment/requirements_v2.txt (line 16)) (1.6.0)
# Requirement already satisfied: audioread>=2.1.9 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from librosa->noisereduce->-r ../environment/requirements_v2.txt (line 16)) (3.0.0)
# Requirement already satisfied: resampy>=0.2.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from librosa->noisereduce->-r ../environment/requirements_v2.txt (line 16)) (0.4.0)
# Requirement already satisfied: numba>=0.45.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from librosa->noisereduce->-r ../environment/requirements_v2.txt (line 16)) (0.55.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from matplotlib->noisereduce->-r ../environment/requirements_v2.txt (line 16)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from matplotlib->noisereduce->-r ../environment/requirements_v2.txt (line 16)) (0.11.0)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3.0,>=2.8.1->moviepy->-r ../environment/requirements_v2.txt (line 18)) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3.0,>=2.8.1->moviepy->-r ../environment/requirements_v2.txt (line 18)) (2.1.0)
# Requirement already satisfied: pillow>=8.3.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from imageio<3.0,>=2.5; python_version >= "3.4"->moviepy->-r ../environment/requirements_v2.txt (line 18)) (9.2.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema<5.0.0,>=4.0.0->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (3.8.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azure-ai-ml->-r ../environment/requirements_v2.txt (line 3)) (3.2.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-telemetry~=1.44.0->azureml-train-automl-client~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.11.10)
# Requirement already satisfied: pygments in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from knack~=0.9.0->azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2.12.0)
# Requirement already satisfied: tabulate in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from knack~=0.9.0->azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.8.10)
# Requirement already satisfied: websocket-client>=0.32.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from docker<6.0.0->azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.3.3)
# Requirement already satisfied: portalocker<3,>=1.0; python_version >= "3.5" and platform_system != "Windows" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msal-extensions<=1.0.0,>=0.3.0->azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2.5.1)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from backports.tempfile->azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.0.post1)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.4.8)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from SecretStorage<4.0.0->azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.8.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (3.2.2)
# Requirement already satisfied: pynacl>=1.0.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.5.0)
# Requirement already satisfied: dotnetcore2<4.0.0,>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataprep<4.3.0a,>=4.2.0a->azureml-dataset-runtime[fuse]~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (3.1.23)
# Requirement already satisfied: azureml-dataprep-rslex~=2.8.0dev0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataprep<4.3.0a,>=4.2.0a->azureml-dataset-runtime[fuse]~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2.8.1)
# Requirement already satisfied: azure-identity==1.7.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataprep<4.3.0a,>=4.2.0a->azureml-dataset-runtime[fuse]~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.7.0)
# Requirement already satisfied: azureml-dataprep-native<39.0.0,>=38.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataprep<4.3.0a,>=4.2.0a->azureml-dataset-runtime[fuse]~=1.44.0->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (38.0.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from Flask->azureml-contrib-services~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from Flask->azureml-contrib-services~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.1.0)
# Requirement already satisfied: pickleshare in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (3.0.28)
# Requirement already satisfied: backcall in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (4.8.0)
# Requirement already satisfied: stack-data in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.3.0)
# Requirement already satisfied: traitlets>=5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (5.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.4)
# Requirement already satisfied: nbformat>=4.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (5.2.0)
# Requirement already satisfied: testpath in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.6.0)
# Requirement already satisfied: defusedxml in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.5.0)
# Requirement already satisfied: jupyter-core in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (4.11.1)
# Requirement already satisfied: bleach in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (5.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from nbconvert<6->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.8.4)
# Requirement already satisfied: pyzmq>=13 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jupyter-client<7->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (23.2.0)
# Requirement already satisfied: ansiwrap in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from papermill<2->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.8.4)
# Requirement already satisfied: tenacity in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from papermill<2->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (8.0.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipykernel->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.6.2)
# Requirement already satisfied: nest-asyncio in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipykernel->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.5.5)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.2.0)
# Requirement already satisfied: jarowinkler<2.0.0,>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from rapidfuzz<3.0.0,>=2.3.0->levenshtein==0.20.2->jiwer->-r ../environment/requirements_v2.txt (line 5)) (1.2.1)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from boto3->smart-open>=1.8.1->gensim->-r ../environment/requirements_v2.txt (line 7)) (0.5.2)
# Requirement already satisfied: botocore<1.24.0,>=1.23.19 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from boto3->smart-open>=1.8.1->gensim->-r ../environment/requirements_v2.txt (line 7)) (1.23.19)
# Requirement already satisfied: heapdict in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from zict>=0.1.3->distributed>=2012.12->auto-sklearn->-r ../environment/requirements_v2.txt (line 9)) (1.0.1)
# Requirement already satisfied: appdirs>=1.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pooch>=1.0->librosa->noisereduce->-r ../environment/requirements_v2.txt (line 16)) (1.4.4)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from numba>=0.45.1->librosa->noisereduce->-r ../environment/requirements_v2.txt (line 16)) (0.38.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jedi>=0.16->ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.8.3)
# Requirement already satisfied: wcwidth in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.7.0)
# Requirement already satisfied: asttokens in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from stack-data->ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (2.0.5)
# Requirement already satisfied: pure-eval in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from stack-data->ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.2.2)
# Requirement already satisfied: executing in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from stack-data->ipython->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.9.1)
# Requirement already satisfied: webencodings in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from bleach->nbconvert<6->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.5.1)
# Requirement already satisfied: textwrap3>=0.9.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ansiwrap->papermill<2->azureml-contrib-notebook~=1.44.0; extra == "contrib"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.9.2)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (6.4.12)
# Requirement already satisfied: Send2Trash>=1.8.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (1.8.0)
# Requirement already satisfied: argon2-cffi in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.15.0)
# Requirement already satisfied: prometheus-client in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (0.14.1)
# Requirement already satisfied: argon2-cffi-bindings in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->azureml-widgets~=1.44.0; extra == "notebooks"->azureml-sdk[contrib,notebooks]->-r ../environment/requirements_v2.txt (line 4)) (21.2.0)
# Building wheels for collected packages: strictyaml
#   Building wheel for strictyaml (setup.py) ... done
#   Created wheel for strictyaml: filename=strictyaml-1.6.1-py3-none-any.whl size=123915 sha256=250a50a51018c17805ed9a23c4331930cdb48211cb65e8ac87304937c06ab856
#   Stored in directory: /home/azureuser/.cache/pip/wheels/24/8b/79/d11bb76d63bc1b37df7bd35dc1e47577eb926b7eb1b619fc2d
# Successfully built strictyaml
# ERROR: fbprophet 0.7.1 requires cmdstanpy==0.9.5, which is not installed.
# ERROR: pycaret 2.3.10 has requirement numba<0.55, but you'll have numba 0.55.2 which is incompatible.
# ERROR: pycaret 2.3.10 has requirement pyyaml<6.0.0, but you'll have pyyaml 6.0 which is incompatible.
# ERROR: pycaret 2.3.10 has requirement scikit-learn==0.23.2, but you'll have scikit-learn 0.24.2 which is incompatible.
# ERROR: pycaret 2.3.10 has requirement scipy<=1.5.4, but you'll have scipy 1.7.0 which is incompatible.
# ERROR: pandas-profiling 3.2.0 has requirement joblib~=1.1.0, but you'll have joblib 0.14.1 which is incompatible.
# ERROR: pandas-profiling 3.2.0 has requirement markupsafe~=2.1.1, but you'll have markupsafe 2.0.1 which is incompatible.
# ERROR: azure-cli 2.39.0 has requirement azure-graphrbac~=0.60.0, but you'll have azure-graphrbac 0.61.1 which is incompatible.
# ERROR: azure-cli 2.39.0 has requirement azure-mgmt-authorization~=0.61.0, but you'll have azure-mgmt-authorization 2.0.0 which is incompatible.
# ERROR: azure-cli 2.39.0 has requirement azure-mgmt-containerregistry==8.2.0, but you'll have azure-mgmt-containerregistry 10.0.0 which is incompatible.
# ERROR: azure-cli 2.39.0 has requirement azure-mgmt-keyvault==9.3.0, but you'll have azure-mgmt-keyvault 10.0.0 which is incompatible.
# ERROR: azure-cli 2.39.0 has requirement azure-mgmt-network~=20.0.0, but you'll have azure-mgmt-network 21.0.1 which is incompatible.
# ERROR: azure-cli 2.39.0 has requirement azure-mgmt-resource==21.1.0b1, but you'll have azure-mgmt-resource 21.1.0 which is incompatible.
# Installing collected packages: azure-storage-file-share, pydash, strictyaml, tqdm, marshmallow, colorama, azure-ai-ml
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.5
#     Uninstalling colorama-0.4.5:
#       Successfully uninstalled colorama-0.4.5
# Successfully installed azure-ai-ml-1.0.0 azure-storage-file-share-12.10.1 colorama-0.4.4 marshmallow-3.18.0 pydash-5.1.1 strictyaml-1.6.1 tqdm-4.63.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Please execute `sudo apt-get install libsndfile1` for preparing audio files on Ubuntu, if needed.

# %% [markdown]
# ## 0.3 Confirm our environment variables
#
# Please check your environment variables with the following cell.

# %%
## We confirm our setting with this cell.

import os, sys
currentDir = os.path.dirname(os.getcwd())
print(f'Current working directory: {currentDir}')
sys.path.append(currentDir)
sys.path.append('./../')
sys.path.append('././')

from dotenv import load_dotenv, find_dotenv
from common.constants import *

print('Loading environmental variables', load_dotenv(find_dotenv(ENVIORNMENT_FILE)))

SUBSCRIPTION_ID = os.environ.get('SUBSCRIPTION_ID')
RESOURCE_GROUP = os.environ.get('RESOURCE_GROUP')
REGION = os.environ.get('REGION')
TENANT_ID = os.environ.get('TENANT_ID')
WORKSPACE_NAME = os.environ.get('WORKSPACE_NAME')
STORAGE_ACCOUNT = os.environ.get('STORAGE_ACCOUNT')
SECRET_KEY = os.environ.get('SECRET_KEY')
SPEECH_KEY = os.environ.get('SPEECH_KEY')
LOCATION=os.environ.get('LOCATION')
TEXT_ANALYTICS_KEY = os.environ.get('TEXT_ANALYTICS_KEY')

print('---- Check Azure setting ----')
print(f'Subscription ID         : {SUBSCRIPTION_ID}')
print(f'Resource group          : {RESOURCE_GROUP}')
print(f'Region                  : {REGION}')
print(f'Tenant                  : {TENANT_ID}')
print(f'AML Workspace           : {WORKSPACE_NAME}')
print(f'Storage account         : {STORAGE_ACCOUNT}')
print(f'Storage secret key      : {SECRET_KEY}')
print(f'Speech key              : {SPEECH_KEY}')
print(f'Text analytics key      : {TEXT_ANALYTICS_KEY}')
# Out:
# Current working directory: /mnt/batch/tasks/shared/LS_root/mounts/clusters/kyiwasak2-speech/code/Users/kyiwasak/dstoolkit-speech-to-text-nlp-mining-accelerator/src
# Loading environmental variables True
# ---- Check Azure setting ----
# Subscription ID         : e9b02ef2-7153-4301-9716-f2f328b39811
# Resource group          : speech2text-kyiwasak
# Region                  : eastus2
# Tenant                  : 2c07d0a7-0d73-4574-a9c5-277f9cda9bb4
# AML Workspace           : speech2text-ws
# Storage account         : speech2textws5431402866
# Storage secret key      : qgMXjSqqtD5i9ai/dV40gNCbFsIS4ZVHTuUd7eUTF125ytttTVKxyN5AzCpKgUOzGkoP7nIlotaM+AStWR/hWQ==
# Speech key              : AAA
# Text analytics key      : AAA

# %% [markdown]
# ## 0.4 Azure ML Configuration

# %%
from azure.ai.ml import MLClient
from azure.ai.ml.entities import Workspace
from azure.identity import DefaultAzureCredential

# get a handle to the subscription
ml_client = MLClient(DefaultAzureCredential(), 
                    subscription_id=SUBSCRIPTION_ID,
                    resource_group_name=RESOURCE_GROUP,
                    workspace_name=WORKSPACE_NAME)
# Out:
# Class SystemCreatedStorageAccount: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SystemCreatedAcrAccount: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class RegistryOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
from common.azureml_configuration_v2 import *

# configure Azure ML services
#-----------------------------
# initilaise the azureml config class
azuremlConfig = AzureMLConfiguration_v2(workspace=WORKSPACE_NAME
                                    ,tenant_id=TENANT_ID
                                    ,subscription_id=SUBSCRIPTION_ID
                                    ,resource_group=RESOURCE_GROUP
                                    ,location=REGION)

# configure Azure ML workspace
ws = azuremlConfig.configWorkspace()

# %%
from common.azureml_configuration_v2 import *

# configure Azure ML services
#-----------------------------
# initilaise the azureml config class
azuremlConfig = AzureMLConfiguration_v2(workspace=WORKSPACE_NAME
                                    ,tenant_id=TENANT_ID
                                    ,subscription_id=SUBSCRIPTION_ID
                                    ,resource_group=RESOURCE_GROUP
                                    ,location=REGION)

# configure Azure ML workspace
azuremlConfig.configWorkspace()

# configure the azure ML compute 
azuremlConfig.configCompute()

# configure the experiment(s)
azuremlConfig.configExperiment(experiment_name=EXPERIMENT_NAME)

# configure the environment - condaa
azuremlConfig.configEnvironment(environment_name=ENVIRONMENT_NAME)

# %% [markdown]
# By setting in `azuremlConfig.configCompute()`, you can use managed identity to retrieve AML workspace in executing batch pipelines. You may make sure the populated managed identity(=`Principal ID`) in red-rectangle.
#
# ![Managed Identity](../../documentation/images/managed_id_computer_cluster.png)
#
# To provision system-assigned identity, please follow the steps.
#
# ![Set Managed Identity](../../documentation/images/set_managed_ID.png)
#
# ![Set System-Assigned Identity](../../documentation/images/system_managed_ID.png)

# %% [markdown]
# After generating the managed identity, you need to assign the appropriate rights like READ or WRITE(IAM) in Azure AD.
#
# - Find application name
#     - Go to `Enterprise Applications` in your `Azure AD`:
#
#         ![Select Enterprise Applications](../../documentation/images/aad_ea.png)
#
#     - Select `All applications` and input your `Principal ID`, which was generated in AML:
#
#         ![Search your application with managed identity](../../documentation/images/all_search_ea.png)
#
#         If you find your application, go to the link:
#
#         ![Go to the link](../../documentation/images/enterprise_application.png)
#
#     - Copy the application name:
#
#         ![Copy application name](../../documentation/images/sp_copy.png)
#
# - Give appropriate rights to the application:
#     - Move to AML pane, provide appropriate rights to application:
#
#         ![Managed Identity](../../documentation/images/iam.png)
#
#     - Use "Select members" to add role assignment.
#
#         ![Add Role Assignment](../../documentation/images/add_role.png)

# %% [markdown]
# ## 0.5 (Sub)directory configuration

# %%
from common.general_utilities import *

# create a temp directory to store results with sub-foldrs
#------------------------------------------------------------
# set the use-case
use_case = 'comms-classification'

# set the correct paths and mounting points
dsp_results_folders = f'{RESULTS_PATH}{RESULTS_DSP_PATH}{use_case}/'
transcripts_results_folder = f'{RESULTS_PATH}{RESULTS_TRANSCRIBE_PATH}{use_case}/' 
assessed_results_folder =  f'{RESULTS_PATH}{RESULTS_ASSESSED_PATH}{use_case}/' 

RECORDINGS_DATASET_NAME = f'{RAW_CONTAINER_NAME}-{use_case}'
TRUTH_DATASET_NAME = f'{TRUTH_TRANSCRIPTS}-{use_case}'
ASSESSED_DATASET_NAME = f'{ASSESSED_CONATINER_NAME}-{use_case}'

RECORDINGS_MOUNT_PATH = f'{MOUNT_PATH_ROOT}{use_case}/{RECORDINGS_FOLDER}'
TRUTH_MOUNT_PATH = f'{MOUNT_PATH_ROOT}{use_case}/{TRUTH_TRANSCRIPTED_FOLDER}'
ONTOLOGY_MOUNT_PATH = f'{MOUNT_PATH_ROOT}{use_case}/{ONTOLOGY_FOLDER}'

# create the results directories - based on the use_case
utilConfig = GeneraltUtilities()
utilConfig.createTmpDir(dsp_results_folders)
utilConfig.createTmpDir(transcripts_results_folder)
utilConfig.createTmpDir(assessed_results_folder)

# %%
# confogure and register the datastore(s) with Azure ML piplines
raw_datastore = azuremlConfig.configDataStore(datastore=RAW_DATASTORE_NAME, container_name=RAW_CONTAINER_NAME)
processed_datastore = azuremlConfig.configDataStore(datastore=DSP_DATASTORE_NAME, container_name=DSP_CONATINER_NAME)
transcribed_datastore = azuremlConfig.configDataStore(datastore=TRANSCRIBED_DATASTORE_NAME, container_name=TRANSCRIBED_CONATINER_NAME)
assessed_datastore = azuremlConfig.configDataStore(datastore=ASSESSED_DATASTORE_NAME, container_name=ASSESSED_CONATINER_NAME)

# %%
## Make container in each container
azuremlConfig.make_directory_in_container(container_name=RAW_CONTAINER_NAME, directory=RECORDINGS_FOLDER)
azuremlConfig.make_directory_in_container(container_name=RAW_CONTAINER_NAME, directory=TRUTH_TRANSCRIPTED_FOLDER)
azuremlConfig.make_directory_in_container(container_name=RAW_CONTAINER_NAME, directory=ONTOLOGY_FOLDER)
azuremlConfig.make_directory_in_container(container_name=ASSESSED_CONATINER_NAME, directory=RESULTS_ASSESSED_PATH)

# %% [markdown]
# ## 0.6 Upload those files
#
# After generating these datastore, we need to upload the provided sample files into the locations as shown in the following tables.
#
# - For training
#
# | container_name     | sub-directory              | file name                                  | contents                  |
# |--------------------|----------------------------|--------------------------------------------|---------------------------|
# | raw                | recordings                 | xxx.wav                                    | Raw audio data.           |
# | raw                | provided-transcripts       | transcripts-truth.csv                      | True transcriptions for raw audio data. |
# | raw                | ontology                   | homophone-list.txt                         | A list of pairs of words with similar pronuciation but different meanings. The latter one word is domian specific. |
# | raw                | ontology                   | key-phrases-to-search.json                 | It defines key phrases to search.|
# | raw                | ontology                   | general-ontology.json      | It defines general ontology.|
# | raw                | ontology                   | message-protocols.json     | It defines compliant message protocols.|
# | raw                | ontology                   | radio-check-ontology.json  | It defines ontology related to radio check.|
#
# - For inference
#
# | container_name     | sub-directory              | file name                                   | contents                 |
# |--------------------|----------------------------|---------------------------------------------|--------------------------|
# | assessed           | assessed                   | xxx.wav                                     | Audio data for assessment.|

# %%
raw_recordings_datasets = azuremlConfig.configDatasets(datastore=raw_datastore, file_path= RECORDINGS_FOLDER, 
                                            dataset_name=RECORDINGS_DATASET_NAME, description='raw datasets')

# %%
# Prepare the datasets
#------------------------
# register the datasets associated with the datastore - recordings
raw_recordings_datasets = azuremlConfig.configDatasets(datastore=raw_datastore, file_path= RECORDINGS_FOLDER, 
                                            dataset_name=RECORDINGS_DATASET_NAME, description='raw datasets')

# register the datasets associated with the datastore - truth transcription provided
truth_transcribed_datasets = azuremlConfig.configDatasets(datastore=raw_datastore, file_path = TRUTH_TRANSCRIPTED_FOLDER, 
                                            dataset_name=TRUTH_DATASET_NAME, description='truth transcripted datasets')

# register the datasets associated with the datastore - key phrases
key_phrases_datasets = azuremlConfig.configDatasets(datastore=raw_datastore, file_path = ONTOLOGY_FOLDER, 
                                            dataset_name=ONTOLOGY_DATASET_NAME, description='ontology datasets')

# register the datasets associated with the datastore - assessed data
assessed_datasets = azuremlConfig.configDatasets(datastore=assessed_datastore, file_path = RESULTS_ASSESSED_PATH, 
                                            dataset_name=ASSESSED_DATASET_NAME, description='assessed datasets')
